# %% [markdown]
# <a href="https://colab.research.google.com/github/IndraNex/bioimage-informatics/blob/main/notebooks/day01_foundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the one package not pre-installed in Colab
# !pip install tifffile -q

# Import core libraries
import numpy as np
import matplotlib.pyplot as plt
import tifffile
